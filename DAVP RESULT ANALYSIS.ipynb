# %% [markdown]
# # RESULT ANALYSIS OF CUTM STUDENTS(2018,2019)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.ticker

# %matplotlib inline

# %%
df = pd.read_csv("davp11.csv")

# %%
df.head()
# Out:
#           REGNO         NAME   SEX                                  SUBJECTS  \
# 0  181801120001  V.NAVANEETH  MALE                       DISCRETEMATHEMATICS
# 1  181801120001  V.NAVANEETH  MALE                     ENVIRONMENTAL SCIENCE
# 2  181801120001  V.NAVANEETH  MALE              APPLIED ANALYTICAL CHEMISTRY
# 3  181801120001  V.NAVANEETH  MALE                 ELECTRICITY AND MAGNETISM
# 4  181801120001  V.NAVANEETH  MALE  BASIC MECHANICS AND PROPERTIES OF MATTER
#
#    BASKET  SEMESTER GRADE RESULT  YEAR
# 0       1         1     O   PASS  2018
# 1       1         1     E   PASS  2018
# 2       1         1     A   PASS  2018
# 3       1         1     C   PASS  2018
# 4       1         1     E   PASS  2018

# %%
df.columns
# Out:
# Index(['REGNO', 'NAME', 'SEX', 'SUBJECTS', 'BASKET', 'SEMESTER', 'GRADE',
#        'RESULT', 'YEAR'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1786 entries, 0 to 1785
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   REGNO     1786 non-null   int64
#  1   NAME      1786 non-null   object
#  2   SEX       1786 non-null   object
#  3   SUBJECTS  1786 non-null   object
#  4   BASKET    1786 non-null   int64
#  5   SEMESTER  1786 non-null   int64
#  6   GRADE     1786 non-null   object
#  7   RESULT    1786 non-null   object
#  8   YEAR      1786 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 125.7+ KB

# %%
df.isnull().sum()
# Out:
# REGNO       0
# NAME        0
# SEX         0
# SUBJECTS    0
# BASKET      0
# SEMESTER    0
# GRADE       0
# RESULT      0
# YEAR        0
# dtype: int64

# %%
print("students:", len(pd.unique(df['REGNO'])))
# Out:
# students: 70

# %%
print("subjects:", len(pd.unique(df['SUBJECTS'])))
# Out:
# subjects: 43

# %%
print("semester:", len(pd.unique(df['SEMESTER'])))
# Out:
# semester: 4

# %%
print("basket:", len(pd.unique(df['BASKET'])))
# Out:
# basket: 4

# %%
pd.unique(df['GRADE'])
# Out:
# array(['O', 'E', 'A', 'C', 'B', 'D', 'F'], dtype=object)

# %%
df = df.rename(columns={'E ': 'E'})

# %%
pd.unique(df['GRADE'])
# Out:
# array(['O', 'E', 'A', 'C', 'B', 'D', 'F'], dtype=object)

# %%
sem1=pd.DataFrame(df.loc[df['SEMESTER'] == 1])
sem2=pd.DataFrame(df.loc[df['SEMESTER'] == 2])
sem3=pd.DataFrame(df.loc[df['SEMESTER'] == 3])
sem4=pd.DataFrame(df.loc[df['SEMESTER'] == 4])

# %%
pd.unique(df['SEMESTER'])
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %% [markdown]
# # ANALYSIS

# %%
    1.Dataset collection:The dataset for the result analysis is prepared by us.We have gathered all the results of 2018 batch of     4 semesters and 2019 batch of 3 semesters.
    2.The total number of rows and columns are 1786 × 8.
    3.The analysis between subject and year in semester-1 is done in a countplot.
    4.The analysis between subject and year in semester-2 is done in a countplot.
    5.The analysis between subject and year in semester-3 is done in a countplot.
    6.The analysis between subject and year in semester-4 is done in a countplot.
    7.Here we have divided the dataset into 2 batches i.e.2018 and 2019.
    8.The analysis between subjects and grades of batch-1with respetc to sem1 is done in a barplot.
    9.The analysis between subjects and grades of batch-1with respect to sem2 is done in a barplot.
    10.The analysis between subjects and grades of batch-1with respect to sem3 is done in a barplot.
    11.The analysis between subjects and grades of batch-1with respect to sem4 is done in a barplot.
    12.The analysis between subjects and grades of batch-2with respect to sem1 is done in a barplot.
    13.The analysis between subjects and grades of batch-2with respect to sem2 is done in a barplot.
    14.The analysis between subjects and grades of batch-2with respect to sem3 is done in a barplot.
    15.The analysis of result of batch1 is given by a  pie chart.
    16.The analysis of result of batch2 is given by a  pie chart.
    17.The analysis between semester and basket of batch-1 done in a countplot.
    18..The analysis between subjects and number of students opted is done in a countplot.
    19.The correlationn of the dataset is done in a heatmap.

# %%
sem1.head()
# Out:
#           REGNO         NAME   SEX                                  SUBJECTS  \
# 0  181801120001  V.NAVANEETH  MALE                       DISCRETEMATHEMATICS
# 1  181801120001  V.NAVANEETH  MALE                     ENVIRONMENTAL SCIENCE
# 2  181801120001  V.NAVANEETH  MALE              APPLIED ANALYTICAL CHEMISTRY
# 3  181801120001  V.NAVANEETH  MALE                 ELECTRICITY AND MAGNETISM
# 4  181801120001  V.NAVANEETH  MALE  BASIC MECHANICS AND PROPERTIES OF MATTER
#
#    BASKET  SEMESTER GRADE RESULT  YEAR
# 0       1         1     O   PASS  2018
# 1       1         1     E   PASS  2018
# 2       1         1     A   PASS  2018
# 3       1         1     C   PASS  2018
# 4       1         1     E   PASS  2018

# %%
pd.crosstab(df['SUBJECTS'],df['GRADE'])
# Out:
# GRADE                                      A  B   C   D   E   F   O
# SUBJECTS
# AI TOOLS, TECHNIQUES AND APPLICATIONS      1  3   6   1   3   7  12
# APPLIED ANALYTICAL CHEMISTRY              16  0  13  15  20   0   6
# APPLIED ENGINEERING MATERIALS              0  0   1   1   1   0   0
# BASIC MECHANICS AND PROPERTIES OF MATTER  31  0   5   6  23   0   5
# BIG DATA ANALYTICS                         2  1  13  13   0   1   3
# BUILD YOUR OWN COMPUTER                   13  1   6  13  21   9   7
# CLOUD COMPUTING AND ITS APPLICATIONS      13  1   9  13  21  11   2
# COMMUNICATIVEPRACTICELAB -1                9  2   3  14  23   9  10
# COMMUNICATIVEPRACTICELAB -2                0  0   0   0   0   0   1
# COMMUNICATIVEPRACTICELAB-2                 1  0   0   0   1   0   0
# COMPILER DESIGN                            8  0   0   5  11   7   2
# COMPUTER NETWORKS                          8  0   1  10   8   6   0
# COMPUTER ORGANISATION AND ARCHITECTURE    19  0   0   2   9   2   1
# ...

# %% [markdown]
# # SEM WISE SUBJECT PLOTS

# %%
sns.countplot(x ='SUBJECTS',data=sem1,hue = 'YEAR')
plt.xticks(rotation=90)
plt.ylim([0, 70])
plt.ylabel('Total strength')
matplotlib.rcParams['figure.figsize'] = (12, 5)

# %%
sns.countplot(x ='SUBJECTS',data=sem2,hue = 'YEAR')
plt.xticks(rotation=90)
plt.ylim([0, 70])
plt.ylabel('Total strength')
matplotlib.rcParams['figure.figsize'] = (12, 5)

# %%
sns.countplot(x ='SUBJECTS',data=sem3,hue = 'YEAR')
plt.xticks(rotation=90)
plt.ylim([0, 70])
plt.ylabel('Total strength')
# Out:
# Text(0, 0.5, 'Total strength')

# %%
sns.countplot(x ='SUBJECTS',data=sem4,hue = 'YEAR')
plt.xticks(rotation=90)
plt.ylim([0, 70])
plt.ylabel('Total strength')
# Out:
# Text(0, 0.5, 'Total strength')

# %% [markdown]
# # BATCH AND SUBJECT GRADES

# %%
batch1=pd.DataFrame(df.loc[df['YEAR'] == 2018])
batch2=pd.DataFrame(df.loc[df['YEAR'] == 2019])

# %%
pd.crosstab(batch1.SUBJECTS,sem1.GRADE).plot(kind="bar",figsize=(22,12))
# Out:
# <AxesSubplot:xlabel='SUBJECTS'>

# %%
pd.crosstab(batch1.SUBJECTS,sem2.GRADE).plot(kind="bar",figsize=(22,12))
# Out:
# <AxesSubplot:xlabel='SUBJECTS'>

# %%
pd.crosstab(batch1.SUBJECTS,sem3.GRADE).plot(kind="bar",figsize=(22,12))
# Out:
# <AxesSubplot:xlabel='SUBJECTS'>

# %%
pd.crosstab(batch1.SUBJECTS,sem4.GRADE).plot(kind="bar",figsize=(22,12))
# Out:
# <AxesSubplot:xlabel='SUBJECTS'>

# %%
pd.crosstab(batch2.SUBJECTS,sem1.GRADE).plot(kind="bar",figsize=(22,12))
# Out:
# <AxesSubplot:xlabel='SUBJECTS'>

# %%
pd.crosstab(batch2.SUBJECTS,sem2.GRADE).plot(kind="bar",figsize=(22,12))
# Out:
# <AxesSubplot:xlabel='SUBJECTS'>

# %%
pd.crosstab(batch2.SUBJECTS,sem3.GRADE).plot(kind="bar",figsize=(22,12))
# Out:
# <AxesSubplot:xlabel='SUBJECTS'>

# %%
plt.figure(figsize=(12,8))
plt.pie(batch1.RESULT.value_counts(),explode=[0.1,0.1],autopct='%.1f%%',shadow=True,labels=['pass','fail'])
plt.axis('equal')
plt.title('pieplot')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.pie(batch2.RESULT.value_counts(),explode=[0.1,0.1],autopct='%.1f%%',shadow=True,labels=['pass','fail'])
plt.axis('equal')
plt.title('pieplot')
plt.show()

# %%
sns.countplot(x ='SEMESTER',data=batch1,hue = 'BASKET')
plt.xticks(rotation=90)
plt.ylim([0, 70])
plt.ylabel('Total strength')
matplotlib.rcParams['figure.figsize'] = (12, 5)

# %%
plt.style.use('dark_background')
plt.figure(figsize=(12,7))
sns.countplot(df.SUBJECTS)
plt.xticks(rotation=90)
plt.title("Age distribution")
# Out:
# C:\Users\Naveena\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Age distribution')

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # CONCLUSION:

# %%
By using this analysis,we have got the compartive analysis of pass percentage.By using the plots we hve got the insights.
The future work of this analysis can be taken to pass percentage of both the year students and the highest grade of each batch.
And in the future we can add the next batch analysis.
